# %%
# !python image_process_after_stack_without_cidre.py
# !python image_process_after_stack_lilab_cy5.py
# Out:
# ...
# CIDRE correcting: 100%|██████████| 4/4 [22:11<00:00, 332.79s/it]
#
# ...
# Copying reference: 100%|██████████| 4/4 [38:28<00:00, 577.01s/it]
#
# ...
# Registering: 100%|██████████| 616/616 [02:44<00:00,  3.75it/s]
#
# ...
# Registering:  22%|██▏       | 134/616 [04:40<16:39,  2.07s/it]
# ...
# ...
# cyc_1_TxRed: 100%|██████████| 616/616 [05:12<00:00,  1.97it/s]
#
# ...
# Stitching: 100%|██████████| 4/4 [11:43<00:00, 175.97s/it]

# %%
# !python multi_channel_readout_15color.py
# Out:
# RUN_ID: 20220918_PRISM_Brain_30plex_DAPI
# 2D_image_shape_y, x: (49108, 62385)
# Image file size: 6127205528 bytes (5.71 GB)
# n_tile: 4;
# x_slice_num: 2; y_slice_num: 2;
# block_x: 31692; block_y: 25054; overlap: 500;
# n_tile: 4;
# x_slice_num: 2; y_slice_num: 2;
# block_x: 31692; block_y: 25054; overlap: 500;
# raw_read: 8933847
# deduplicate: 6987297
# deduplicate: 6987297
# Removed .dat files
# ...
# tile: 100%|██████████| 4/4 [2:35:04<00:00, 2326.07s/it]
#
# ...
# tile: 100%|██████████| 4/4 [00:03<00:00,  1.03it/s]

# %%
# !python multi_channel_readout_15color.py

# %%
# !python gene_calling_GMM.py
